# %%
import matplotlib.pyplot as plt
import numpy as np
x=['A','B','C','D']
y=[100,200,50,150]
colorlist=['red','blue','green','orange']
plt.bar(x,y,color=colorlist,width=0.9)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
companyname=['amazon','flipcart']
revenue=[200,300]

plt.xlabel("company name")
plt.ylabel("revenue")
plt.title("comparision data")
plt.barh(companyname,revenue,height=0.4)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
companyname=['amazon','flipcart']
revenue=[200,300]

plt.xlabel("company name")
plt.ylabel("revenue")
plt.title("comparision data")
plt.bar(companyname,revenue,width=0.4)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=[210,120,340,570,190]
col=['r','g','b','c','m']
plt.pie(x,labels=['AI','RAI','CSD','CE','IT'],colors=col,startangle=90,counterclock=False,radius=2,shadow=True,autopct='%1.f%%',explode=[0.2,0,0,0,0])
plt.show()

# %%
import matplotlib.pyplot as plt
x=[1,2,3,1,2,3,1,2,3,3,2]
plt.hist(x,bins=2,orientation='vertical',align='mid',color='g',histtype='stepfilled')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x=[61,63,64,66,67,68,69,71,71.5,72,72.5,73,73.5,74,74.5,76,76.2,76.5, 77, 77.5, 78, 78.5, 79, 79.2, 80, 81, 82, 83, 84, 85, 87]
f={'size':20}
plt.hist(x,color='g',bins=[61,65,70,75,80,87])
plt.title("Height of trees",fontdict=f)
# plt.show()
# Out:
# Text(0.5, 1.0, 'Height of trees')

# %%
import matplotlib.pyplot as plt
import numpy as np
x1=[5,10,25,60,80]
y1=[5,17,25,40,30]
plt.subplot(3,2,1)
plt.plot(x1,y1,"d:g")
plt.title("first")
plt.xlabel("x-axis")
plt.ylabel("y-axis")

Scores_men = [22, 30, 35, 35, 26]
Scores_women = [25, 32, 30, 35, 29]
plt.subplot(3,2,2)
plt.bar(Scores_men,Scores_women)
plt.xlabel('Scores_men')
plt.ylabel('Scores_women')
# Out:
# Text(0, 0.5, 'Scores_women')
